# %% [markdown]
# # -------------------------------------------------------------------------------------¶
# # -------------------------------------------------------------------------------------
# # Name - Dheeraj Atul Salokhe
# # Student No:- x23216905
# # Database & Analytics Programming (MSCDAD_A_JAN24I)
# # -------------------------------------------------------------------------------------
# # -------------------------------------------------------------------------------------

# %% [markdown]
# # Installed Packages

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas matplotlib seaborn mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Libraries

# %%
import json 
import pandas as pd
import mysql.connector as mysql
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Get the current working Directory in Python

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\dheer\OneDrive\Documents\GitHub\GroupH

# %% [markdown]
# # File Extraction

# %%
import json
import pandas as pd

# Load JSON data from a file
with open('historical_emissions Co2 1.json', 'r') as file:

    data = json.load(file)

# Convert nested JSON into a flat DataFrame
df = pd.json_normalize(data, record_path=['data', 'emissions'], meta=[['data', 'id'], 
                                                                     ['data', 'iso_code3'],
                                                                     ['data', 'country'],
                                                                     ['data', 'data_source'],
                                                                     ['data', 'sector'],
                                                                     ['data', 'gas'],
                                                                     ['data', 'unit']],
                       record_prefix='emissions_')

# Save the DataFrame to a CSV file
df.to_csv('Gas Emissions from World.csv', index=False)

# %% [markdown]
# # Load Data into MongoDB

# %%
import pandas as pd
from pymongo import MongoClient

# Load data from CSV
csv_file = "Gas Emissions from World.csv"
data = pd.read_csv(csv_file)


# Setup MongoDB connection
client = MongoClient("mongodb+srv://x23173815:harsh@cluster0.ayuzwdf.mongodb.net/")
db = client["Dataset"]
collection = db["Gas Emissions from World"]


# Convert DataFrame to dictionary
data_dict2 = data.to_dict("records")

# Insert data into MongoDB
collection.insert_many(data_dict2)

# Retrieve and print the first five documents from the collection
for doc in collection.find().limit(5):
    print(doc)

all_documents2 = collection.find()

#for doc in all_documents:
    #print(doc)

#print(all_documents2)

list_cursor2 = list(all_documents2)

print(list_cursor2)

gas_df2 = pd.DataFrame(list_cursor2)
# Out:
# {'_id': ObjectId('662d395c4b1b20aeb4dc8ad4'), 'emissions_year': 1850, 'emissions_value': 0.0, 'data.id': 998262, 'data.iso_code3': 'ABW', 'data.country': 'Aruba', 'data.data_source': 'PIK', 'data.sector': 'Energy', 'data.gas': 'CH4', 'data.unit': 'MtCOâ‚‚e'}
# {'_id': ObjectId('662d395c4b1b20aeb4dc8ad5'), 'emissions_year': 1851, 'emissions_value': 0.0, 'data.id': 998262, 'data.iso_code3': 'ABW', 'data.country': 'Aruba', 'data.data_source': 'PIK', 'data.sector': 'Energy', 'data.gas': 'CH4', 'data.unit': 'MtCOâ‚‚e'}
# {'_id': ObjectId('662d395c4b1b20aeb4dc8ad6'), 'emissions_year': 1852, 'emissions_value': 0.0, 'data.id': 998262, 'data.iso_code3': 'ABW', 'data.country': 'Aruba', 'data.data_source': 'PIK', 'data.sector': 'Energy', 'data.gas': 'CH4', 'data.unit': 'MtCOâ‚‚e'}
# ...

# %%
gas_df2.head()
# Out:
#                         _id  emissions_year  emissions_value  data.id  \
# 0  662d395c4b1b20aeb4dc8ad4            1850              0.0   998262
# 1  662d395c4b1b20aeb4dc8ad5            1851              0.0   998262
# 2  662d395c4b1b20aeb4dc8ad6            1852              0.0   998262
# 3  662d395c4b1b20aeb4dc8ad7            1853              0.0   998262
# 4  662d395c4b1b20aeb4dc8ad8            1854              0.0   998262
#
#   data.iso_code3 data.country data.data_source data.sector data.gas data.unit
# 0            ABW        Aruba              PIK      Energy      CH4  MtCOâ‚‚e
# 1            ABW        Aruba              PIK      Energy      CH4  MtCOâ‚‚e
# 2            ABW        Aruba              PIK      Energy      CH4  MtCOâ‚‚e
# 3            ABW        Aruba              PIK      Energy      CH4  MtCOâ‚‚e
# 4            ABW        Aruba              PIK      Energy      CH4  MtCOâ‚‚e

# %%
gas_df2.tail()
# Out:
#                             _id  emissions_year  emissions_value  data.id  \
# 91723  66319052cebfc57d5577ee7a            2016              0.0   987180
# 91724  66319052cebfc57d5577ee7b            2017              0.0   987180
# 91725  66319052cebfc57d5577ee7c            2018              0.0   987180
# 91726  66319052cebfc57d5577ee7d            2019              0.0   987180
# 91727  66319052cebfc57d5577ee7e            2020              0.0   987180
#
#       data.iso_code3 data.country data.data_source            data.sector  \
# 91723            AFG  Afghanistan    Climate Watch  Other Fuel Combustion
# 91724            AFG  Afghanistan    Climate Watch  Other Fuel Combustion
# 91725            AFG  Afghanistan    Climate Watch  Other Fuel Combustion
# 91726            AFG  Afghanistan    Climate Watch  Other Fuel Combustion
# 91727            AFG  Afghanistan    Climate Watch  Other Fuel Combustion
#
#       data.gas data.unit
# 91723      CH4  MtCOâ‚‚e
# ...

# %%
gas_df2.shape
# Out:
# (91728, 10)

# %%
gas_df2.describe()
# Out:
#        emissions_year  emissions_value        data.id
# count    91728.000000     90984.000000   91728.000000
# mean      1955.028257         1.062825  995206.777865
# std         52.718045         3.530686    4963.329089
# min       1850.000000        -2.390000  987147.000000
# 25%       1909.000000         0.000000  987177.000000
# 50%       1969.000000         0.000000  998266.000000
# 75%       2002.000000         0.170000  998272.000000
# max       2022.000000        32.890000  998277.000000

# %%
print(gas_df2.isnull().sum())
# Out:
# _id                   0
# emissions_year        0
# emissions_value     744
# data.id               0
# data.iso_code3        0
# data.country          0
# data.data_source      0
# data.sector           0
# data.gas              0
# data.unit             0
# dtype: int64

# %%
gas_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91728 entries, 0 to 91727
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               91728 non-null  object
#  1   emissions_year    91728 non-null  int64
#  2   emissions_value   90984 non-null  float64
#  3   data.id           91728 non-null  int64
#  4   data.iso_code3    91728 non-null  object
#  5   data.country      91728 non-null  object
#  6   data.data_source  91728 non-null  object
#  7   data.sector       91728 non-null  object
#  8   data.gas          91728 non-null  object
#  9   data.unit         91728 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.0+ MB

# %%
print(gas_df2.columns.tolist())
# Out:
# ['_id', 'emissions_year', 'emissions_value', 'data.id', 'data.iso_code3', 'data.country', 'data.data_source', 'data.sector', 'data.gas', 'data.unit']

# %% [markdown]
# # Data Cleaning

# %%
gas_df2.drop(['data.data_source','data.unit'],axis = 1, inplace = True)

# %%
gas_df2
# Out:
#                             _id  emissions_year  emissions_value  data.id  \
# 0      662d395c4b1b20aeb4dc8ad4            1850              0.0   998262
# 1      662d395c4b1b20aeb4dc8ad5            1851              0.0   998262
# 2      662d395c4b1b20aeb4dc8ad6            1852              0.0   998262
# 3      662d395c4b1b20aeb4dc8ad7            1853              0.0   998262
# 4      662d395c4b1b20aeb4dc8ad8            1854              0.0   998262
# ...                         ...             ...              ...      ...
# 91723  66319052cebfc57d5577ee7a            2016              0.0   987180
# 91724  66319052cebfc57d5577ee7b            2017              0.0   987180
# 91725  66319052cebfc57d5577ee7c            2018              0.0   987180
# 91726  66319052cebfc57d5577ee7d            2019              0.0   987180
# 91727  66319052cebfc57d5577ee7e            2020              0.0   987180
#
#       data.iso_code3 data.country            data.sector data.gas
# ...

# %% [markdown]
# # Loading MySQL

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as mysql
from sqlalchemy import create_engine

# %%
#Parameter for database
host = 'localhost'
user = 'root'
password = 'root'
database = 'grouph'

# Connection establishment
connection = mysql.connect(
host=host,
user=user,
password=password,
database=database
)

if connection.is_connected():
    print("Connected to MySQL database")
# Out:
# Connected to MySQL database

# %%
gas_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91728 entries, 0 to 91727
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              91728 non-null  object
#  1   emissions_year   91728 non-null  int64
#  2   emissions_value  90984 non-null  float64
#  3   data.id          91728 non-null  int64
#  4   data.iso_code3   91728 non-null  object
#  5   data.country     91728 non-null  object
#  6   data.sector      91728 non-null  object
#  7   data.gas         91728 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 5.6+ MB

# %%
# creates a table named gas_emissions_from_world in a SQL database:
cursor = connection.cursor()
query = """
   CREATE TABLE gas_emissions_from_world(
        `_id` VARCHAR(255) PRIMARY KEY,
        `emissions_year` INT,
        `emissions_value` FLOAT,
        `data.id` INT,
        `data.iso_code3` VARCHAR(10),
        `data.country` VARCHAR(100),
        `data.sector` VARCHAR(100),
        `data.gas` VARCHAR(50)
  )
"""
cursor.execute(query)

# Remember to commit your changes if your database requires it.
connection.commit()
cursor.close()
# Out:
# True

# %% [markdown]
# # Fetch data using SQL query & plot graph

# %%
#prints a MySQL connection string:
connection_string = f'mysql+pymysql://{user}:{password}@{host}/{database}'

print(connection_string)
# Out:
# mysql+pymysql://root:root@localhost/grouph

# %%
engine = create_engine(connection_string)

# %%
gas_df2.to_sql(name='gas_emissions_from_world', con=engine, if_exists='append', index=False)
# Out:
# 91728

# %% [markdown]
# # SQL Query to check the condition (Condition-1):

# %%
cursor = connection.cursor()
query = "SELECT * FROM gas_emissions_from_world ORDER BY _id DESC LIMIT 10"

cursor.execute(query)

results = cursor.fetchall()

for row in results:
    print(row)

cursor.close()
# Out:
# ('66319052cebfc57d5577ee7e', 2020, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ('66319052cebfc57d5577ee7d', 2019, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ('66319052cebfc57d5577ee7c', 2018, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ('66319052cebfc57d5577ee7b', 2017, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ('66319052cebfc57d5577ee7a', 2016, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ('66319052cebfc57d5577ee79', 2015, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ('66319052cebfc57d5577ee78', 2014, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ('66319052cebfc57d5577ee77', 2013, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ('66319052cebfc57d5577ee76', 2012, 0.0, 987180, 'AFG', 'Afghanistan', 'Other Fuel Combustion', 'CH4')
# ...

# %% [markdown]
# # SQL Query to check the condition (Condition-2):

# %%
cursor = connection.cursor()

query = "SELECT * FROM gas_emissions_from_world WHERE emissions_value > 1.1"

cursor.execute(query)
 
results = cursor.fetchall()
 
for row in results:

    print(row)
 
plot_1 = pd.read_sql(query, connection)
 
cursor.close()
# Out:
# ('662d395c4b1b20aeb4dc8bcd', 1926, 1.25, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bce', 1927, 1.23, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bcf', 1928, 3.23, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bd0', 1929, 4.05, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bd1', 1930, 4.96, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bd2', 1931, 4.22, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bd3', 1932, 4.1, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bd4', 1933, 4.37, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bd5', 1934, 4.87, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bd6', 1935, 5.62, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8bd7', 1936, 6.01, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ...

# %%
# Preview the first few rows of the DataFrame
print(plot_1.head())
# Out:
#                         _id  emissions_year  emissions_value  data.id  \
# 0  662d395c4b1b20aeb4dc8bcd            1926             1.25   998263
# 1  662d395c4b1b20aeb4dc8bce            1927             1.23   998263
# 2  662d395c4b1b20aeb4dc8bcf            1928             3.23   998263
# 3  662d395c4b1b20aeb4dc8bd0            1929             4.05   998263
# 4  662d395c4b1b20aeb4dc8bd1            1930             4.96   998263
#
#   data.iso_code3 data.country data.sector data.gas
# 0            ABW        Aruba      Energy      CO2
# 1            ABW        Aruba      Energy      CO2
# 2            ABW        Aruba      Energy      CO2
# 3            ABW        Aruba      Energy      CO2
# 4            ABW        Aruba      Energy      CO2

# %% [markdown]
# # Visualization of the 'Emission Value' Vs 'Year'

# %%
plt.figure(figsize=(6, 6))
sns.lineplot(data=plot_1, x='emissions_year', y='emissions_value', hue='data.country')
plt.title('Trend of Emissions Values Over Years by Country')
plt.xlabel('Year')
plt.ylabel('Emissions Value')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\dheer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dheer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # SQL Query to check the condition (Condition-3):

# %%
cursor = connection.cursor()
query = """
SELECT * FROM gas_emissions_from_world WHERE emissions_year = 2010 
"""
cursor.execute(query)
 
results = cursor.fetchall()
 
for row in results:
    print(row)
 
plot_2 = pd.read_sql(query, connection)
 
cursor.close()
# Out:
# ('662d395c4b1b20aeb4dc8b74', 2010, 0.02, 998262, 'ABW', 'Aruba', 'Energy', 'CH4')
# ('662d395c4b1b20aeb4dc8c21', 2010, 2.51, 998263, 'ABW', 'Aruba', 'Energy', 'CO2')
# ('662d395c4b1b20aeb4dc8cce', 2010, 2.54, 998264, 'ABW', 'Aruba', 'Energy', 'KYOTOGHG')
# ('662d395c4b1b20aeb4dc8d7b', 2010, 0.01, 998265, 'ABW', 'Aruba', 'Energy', 'N2O')
# ('662d395c4b1b20aeb4dc8e28', 2010, 0.0, 998266, 'ABW', 'Aruba', 'Industrial Processes and Product Use', 'CO2')
# ('662d395c4b1b20aeb4dc8ed5', 2010, 0.0, 998267, 'ABW', 'Aruba', 'Industrial Processes and Product Use', 'KYOTOGHG')
# ('662d395c4b1b20aeb4dc8f82', 2010, 0.0, 998268, 'ABW', 'Aruba', 'Industrial Processes and Product Use', 'N2O')
# ('662d395c4b1b20aeb4dc902f', 2010, 0.01, 998269, 'ABW', 'Aruba', 'Other', 'KYOTOGHG')
# ('662d395c4b1b20aeb4dc90dc', 2010, 0.01, 998270, 'ABW', 'Aruba', 'Other', 'N2O')
# ('662d395c4b1b20aeb4dc9189', 2010, 0.04, 998271, 'ABW', 'Aruba', 'Total excluding LULUCF', 'CH4')
# ...

# %%
print(plot_2)
# Out:
#                            _id  emissions_year  emissions_value  data.id  \
# 0     662d395c4b1b20aeb4dc8b74            2010             0.02   998262
# 1     662d395c4b1b20aeb4dc8c21            2010             2.51   998263
# 2     662d395c4b1b20aeb4dc8cce            2010             2.54   998264
# 3     662d395c4b1b20aeb4dc8d7b            2010             0.01   998265
# 4     662d395c4b1b20aeb4dc8e28            2010             0.00   998266
# ...                        ...             ...              ...      ...
# 1195  66319052cebfc57d5577edf8            2010             0.00   987176
# 1196  66319052cebfc57d5577ee17            2010             0.00   987177
# 1197  66319052cebfc57d5577ee36            2010             0.00   987178
# 1198  66319052cebfc57d5577ee55            2010             0.00   987179
# 1199  66319052cebfc57d5577ee74            2010             0.00   987180
#
#      data.iso_code3 data.country                           data.sector  \
# ...

# %% [markdown]
# # Visualization of the 'Emissions(Units)' Vs 'Country'

# %%
plt.figure(figsize=(4, 4))
plt.bar(plot_2['data.country'], plot_2['emissions_value'], color='green')
plt.xlabel('Country')
plt.ylabel('Emissions (units)')
plt.title('Gas Emissions by Country in 2010')
plt.show()
